# %% [markdown]
# # Using YOLO (You Only Look Once) for image classification in PyTorch

# %% [markdown]
# ## Frame the Problem

# %% [markdown]
# 1. What is the **Business Objective** in Building this Machine Learning Model?
#     - **Goal:** To identify objects in images
#
# 2. How does the company expect to use and benefit from this model?
#     - ?
#
# 3. Performance Metrics Used
#     - Primarily **Accuracy**, we are focused on correctly classifying the correct image to the correct label.
#
# 4. Assumptions Made
#     1.

# %% [markdown]
# ## Install YOLO and PyTorch in Env

# %% [markdown]
# pip uninstall -y torch torchvision ultralytics
#
# #install pytorch
# pip install torch torchvision --index-url https://download.pytorch.org/whl/cpu
# #install YOLOv8
# pip install ultralytics

# %% [markdown]
# ##  Imports

# %%
from ultralytics import YOLO
import os
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/ryann/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## Get the data

# %%
#prep dataset

# %% [markdown]
# ## EDA

# %%
#exploratory data analysis

# %% [markdown]
# ## Prepare the data and model for training

# %%
#data and model prep

# %% [markdown]
# ## Select, train, and fine-tune the model

# %%
#model is YOLOv8 nano for now
model = YOLO("yolov8n-cls.pt")
#model training

#model fine-tuning

# %% [markdown]
# ## Create, Evaluate, and Save the Finalized Model

# %%
#model.summary()
#model evaluation

# %% [markdown]
# ## Model predictions

# %%
#model predicts

# %% [markdown]
# ## Display predictions

# %%
#model predictions

# %% [markdown]
# ## anything else?
